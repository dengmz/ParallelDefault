# %%
using PyPlot; const plt = PyPlot;

# %%
gpu_7ntime = 
[
    100,
    250,
    500,
    750,
    1000,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000,
    11250,
    12500,
    13750,
    15000,
    16250,
    17500,
    18750,
    20000
]
cpu_7ntime = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000,
    1250,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000
]
cpu_time_7nvr = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000 
]

gpu_7nvr =
[
    0.001481135,
    0.00307305,
    0.00767661,
    0.01085435,
    0.02962163,
    0.04524693,
    0.116920535,
    0.2339817,
    0.46888795,
    0.89888986,
    1.66428956,
    2.080236305,
    2.71625348,
    3.186641435,
    3.68870817,
    4.314977035,
    5.185501565,
    5.856631085,
    6.526113985
]
gpu_7ndecide = 
[
    0.00001671,
    1.56999E-05,
    0.00001579,
    1.59199E-05,
    0.00001713,
    1.87301E-05,
    1.596E-05,
    1.54999E-05,
    0.00001615,
    1.64701E-05,
    1.62401E-05,
    0.00001582,
    1.61399E-05,
    0.00001616,
    0.00001639,
    0.0000157,
    1.61701E-05,
    0.00001588,
    0.00001696
]

cpu_7nvr =
[
    0.001082981,
    0.321565953,
    0.650970059,
    1.31679234,
    2.305363916,
    5.36679004,
    10.3433655,
]
cpu_7ndecide =
[
    1.3362E-05,
    0.002195104,
    0.003187973,
    0.0040663,
    0.005614731,
    0.008266143,
    0.012104929,
    0.014702145,
    0.018612573,
    0.030095512,
    0.04126148,
    0.049021429,
    0.076560898,
    0.100674108
]

#Begin Plotting

fig,(ax1,ax2) = plt.subplots(2)

fig.set_figheight(10)
fig.set_figwidth(14)

ax1.plot(7*cpu_time_7nvr, cpu_7nvr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(7*gpu_7ntime,gpu_7nvr,lw=2, marker ="o",markersize=5, linestyle="--")

ax1.set_title("Comparison: Value of Repayment, Julia vs Julia CUDA")

ax2.plot(7*cpu_7ntime, cpu_7ndecide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(7*gpu_7ntime,gpu_7ndecide,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["Julia", "Julia CUDA"])
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax2.set_title("Comparison: Decision, Julia vs Julia CUDA")
# Out:
# Figure(PyObject <Figure size 1400x1000 with 2 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')

# %%
gpu_n2time = 
[
    100,
    125,
    150,
    200,
    250,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750
]
cpu_n2time_vd = 
[
    25,
    50,
    75,
    100,
    125,
    150,
    175,
    200,
    250,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750
]
cpu_n2time_decide = 
[
    25,
    50,
    75,
    100,
    125,
    150,
    175,
    200
]
cpu_time_n2vr = 
[
    25,
    50,
    75,
    100,
    125
]
gpu_n2vd = 
[
    0.0048269,
    0.0060002,
    0.007170599,
    0.0093563,
    0.0117676,
    0.014054299,
    0.01640905,
    0.019088199,
    0.023234099,
    0.022988699,
    0.02863265,
    0.02893155,
    0.0311247,
    0.033381101,
    0.03514595
]
gpu_n2vr =
[
    0.021742605,
    0.03420152,
    0.04678444,
    0.16335137,
    0.31863086,
    0.62664573,
    1.21444019,
    1.96703706,
    2.954906045,
    4.42985646,
    6.857692565,
    9.17047126,
    10.65110112,
    17.1531411,
    22.27869476
]
gpu_n2decide = 
[
    1.74E-05,
    2.06E-05,
    2.30E-05,
    0.00149893,
    0.003058925,
    0.00465002,
    0.0092637,
    0.01234142,
    0.018653475,
    0.02483498,
    0.03282266,
    0.0432739,
    0.05611574,
    0.07028079,
    0.0843548
]

cpu_n2vd = 
[
    0.0001364,
    0.00053109,
    0.00123273,
    0.00237229,
    0.00357316,
    0.0057178,
    0.00729225,
    0.009179125,
    0.01428472,
    0.02010567,
    0.03180941,
    0.0370611,
    0.04510648,
    0.06104513,
    0.067825935,
    0.08898902,
    0.10190483,
    0.11908736,
    0.13222472
]
cpu_n2vr =
[
    0.055270205,
    0.81490575,
    4.26258664,
    13.87689287,
    31.64415038
]
cpu_n2decide =
[
    0.00261786,
    0.020875015,
    0.07304889,
    0.16992249,
    0.334118665,
    0.58950077,
    0.88454872,
    1.33527905
]

#Begin Plotting

fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(cpu_n2time_vd.^2, cpu_n2vd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(gpu_n2time.^2,gpu_n2vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["Julia", "Julia CUDA"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, Julia vs Julia CUDA")

ax2.plot(cpu_time_n2vr.^2, cpu_n2vr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(gpu_n2time.^2,gpu_n2vr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, Julia vs Julia CUDA")

ax3.plot(cpu_n2time_decide.^2, cpu_n2decide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean runtime (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(gpu_n2time.^2,gpu_n2decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, Julia vs Julia CUDA")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, Julia vs Julia CUDA')

# %%
gpu_7ntime = 
[
    100,
    250,
    500,
    750,
    1000,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000,
    11250,
    12500,
    13750,
    15000,
    16250,
    17500,
    18750,
    20000
]

stdpar_7ntime = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000,
    1250,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000,
    11250,
    12500,
    15000

]

gpu_7nvr =
[
    0.001481135,
    0.00307305,
    0.00767661,
    0.01085435,
    0.02962163,
    0.04524693,
    0.116920535,
    0.2339817,
    0.46888795,
    0.89888986,
    1.66428956,
    2.080236305,
    2.71625348,
    3.186641435,
    3.68870817,
    4.314977035,
    5.185501565,
    5.856631085,
    6.526113985
]

gpu_7ndecide = 
[
    0.00001671,
    1.56999E-05,
    0.00001579,
    1.59199E-05,
    0.00001713,
    1.87301E-05,
    1.596E-05,
    1.54999E-05,
    0.00001615,
    1.64701E-05,
    1.62401E-05,
    0.00001582,
    1.61399E-05,
    0.00001616,
    0.00001639,
    0.0000157,
    1.61701E-05,
    0.00001588,
    0.00001696
]

stdpar_7nvr =
[
    0.000254549,
    0.000733832,
    0.00146435,
    0.00337408,
    0.00558898,
    0.0119738,
    0.0211071,
    0.0359748,
    0.0475067,
    0.138043,
    0.33734,
    0.613225,
    1.32263,
    2.32161,
    2.9288,
    3.43521,
    4.58009

]
stdpar_7ndecide =
[
    1.19654E-05,
    1.93947E-05,
    2.80442E-05,
    4.26068E-05,
    4.96262E-05,
    7.30697E-05,
    9.79587E-05,
    0.000121898,
    0.000153834,
    0.000270114,
    0.000523003,
    0.000544792,
    0.000790248,
    0.00103786,
    0.00119696,
    0.00136703,
    0.00158234

]

#Begin Plotting

fig,(ax1,ax2) = plt.subplots(2)
fig.set_figheight(10)
fig.set_figwidth(14)


ax1.plot(7*stdpar_7ntime, stdpar_7nvr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(7*gpu_7ntime,gpu_7nvr,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["Stdpar", "Julia CUDA"],loc="right")
#fig.legend(["Value of Repayment_stdpar", "Value of Repayment_GPU"])
ax1.set_title("Comparison: Value of Repayment, Stdpar vs Julia CUDA")

ax2.plot(7*stdpar_7ntime, stdpar_7ndecide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(7*gpu_7ntime,gpu_7ndecide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_stdpar", "Decision_GPU"])
ax2.set_title("Comparison: Decision, Stdpar vs Julia CUDA")
# Out:
# Figure(PyObject <Figure size 1400x1000 with 2 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, Stdpar vs Julia CUDA')

# %%
gpu_n2time = 
[
    100,
    125,
    150,
    200,
    250,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750
]
stdpar_n2time = 
[
    50,
    75,
    100,
    125,
    150,
    175,
    200,
    250,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750

]
stdpar_time_n2vr = 
[
    50,
    75,
    100,
    125,
    150,
    175,
    200,
    250,
    300,
    350,
    400

]

gpu_n2vd = 
[
    0.0048269,
    0.0060002,
    0.007170599,
    0.0093563,
    0.0117676,
    0.014054299,
    0.01640905,
    0.019088199,
    0.023234099,
    0.022988699,
    0.02863265,
    0.02893155,
    0.0311247,
    0.033381101,
    0.03514595
]
gpu_n2vr =
[
    0.021742605,
    0.03420152,
    0.04678444,
    0.16335137,
    0.31863086,
    0.62664573,
    1.21444019,
    1.96703706,
    2.954906045,
    4.42985646,
    6.857692565,
    9.17047126,
    10.65110112,
    17.1531411,
    22.27869476
]
gpu_n2decide = 
[
    1.74E-05,
    2.06E-05,
    2.30E-05,
    0.00149893,
    0.003058925,
    0.00465002,
    0.0092637,
    0.01234142,
    0.018653475,
    0.02483498,
    0.03282266,
    0.0432739,
    0.05611574,
    0.07028079,
    0.0843548
]

stdpar_n2vd = 
[
    2.69016E-06,
    5.27081E-06,
    9.16423E-06,
    1.50611E-05,
    2.22364E-05,
    0.00010776,
    3.80147E-05,
    0.000206036,
    9.69854E-05,
    0.000181729,
    0.000208585,
    0.000261079,
    0.000400222,
    0.000572342,
    0.00046453,
    0.000692935,
    0.000725792,
    0.000852845

]
stdpar_n2vr =
[
    0.00357248,
    0.0181688,
    0.0609958,
    0.167618,
    0.350442,
    0.706286,
    1.18726,
    3.11978,
    6.3988,
    12.2222,
    20.5257
]
stdpar_n2decide =
[
    0.000222083,
    0.000787701,
    0.00183217,
    0.00429186,
    0.00633649,
    0.0102133,
    0.0149371,
    0.030141,
    0.0521419,
    0.0817523,
    0.125311,
    0.178184,
    0.246801,
    0.327979,
    0.450835,
    0.535094,
    0.679731,
    0.957906

]

#Begin Plotting

fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(stdpar_n2time.^2, stdpar_n2vd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(gpu_n2time.^2,gpu_n2vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["Stdpar", "Julia CUDA"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, Stdpar vs Julia CUDA")

ax2.plot(stdpar_time_n2vr.^2, stdpar_n2vr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(gpu_n2time.^2,gpu_n2vr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_stdpar", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, Stdpar vs Julia CUDA")

ax3.plot(stdpar_n2time.^2, stdpar_n2decide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean runtime (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(gpu_n2time.^2,gpu_n2decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_stdpar", "Decision_GPU"])
ax3.set_title("Comparison: Decision, Stdpar vs Julia CUDA")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, Stdpar vs Julia CUDA')

# %%
fig,ax1 = plt.subplots(1)
ax1.plot(gpu_n2time.^2, gpu_n2vd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.plot(gpu_n2time.^2, gpu_n2vr, lw=2,color = "purple", marker ="o",markersize=5, linestyle="--")
ax1.plot(gpu_n2time.^2, gpu_n2decide, lw=2, marker ="o",markersize=5, linestyle="--")

ax1.set_ylabel("median (μs)") 
ax1.set_xlabel("Grid Size")
fig.legend(["Value of Default", "Value of Repayment", "Decision"])
fig.set_figheight(10)
fig.set_figwidth(14)
ax1.set_title("Benchmark of Three Components of Default Model by GPU")
# Out:
# Figure(PyObject <Figure size 1400x1000 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'Benchmark of Three Components of Default Model by GPU')
