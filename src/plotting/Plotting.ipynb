# %%
using PyPlot; const plt = PyPlot;

# %%
gpu_7ntime = 
[
    100,
    250,
    500,
    750,
    1000,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000,
    11250,
    12500,
    13750,
    15000,
    16250,
    17500,
    18750,
    20000
]
cpu_7ntime = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000,
    1250,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000
]
cpu_time_7nvr = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000 
]
gpu_7nvd = 
[
    0.00005137,
    5.04899E-05,
    5.118E-05,
    0.00005167,
    0.00005347,
    5.54299E-05,
    0.00005179,
    5.076E-05,
    0.00004976,
    0.00005007,
    5.047E-05,
    0.0000498,
    0.00004958,
    0.00004906,
    0.00005281,
    4.94001E-05,
    5.10401E-05,
    4.92799E-05,
    0.00005037
]
gpu_7nvr =
[
    0.001481135,
    0.00307305,
    0.00767661,
    0.01085435,
    0.02962163,
    0.04524693,
    0.116920535,
    0.2339817,
    0.46888795,
    0.89888986,
    1.66428956,
    2.080236305,
    2.71625348,
    3.186641435,
    3.68870817,
    4.314977035,
    5.185501565,
    5.856631085,
    6.526113985
]
gpu_7ndecide = 
[
    0.00001671,
    1.56999E-05,
    0.00001579,
    1.59199E-05,
    0.00001713,
    1.87301E-05,
    1.596E-05,
    1.54999E-05,
    0.00001615,
    1.64701E-05,
    1.62401E-05,
    0.00001582,
    1.61399E-05,
    0.00001616,
    0.00001639,
    0.0000157,
    1.61701E-05,
    0.00001588,
    0.00001696
]

cpu_7nvd = 
[
    0.000029513,
    0.002595088,
    0.003920655,
    0.005585921,
    0.007276034,
    0.0098881,
    0.014520751,
    0.017932855,
    0.021650492,
    0.03506699,
    0.046521847,
    0.057261686,
    0.085886324,
    0.116654339
]
cpu_7nvr =
[
    0.001082981,
    0.321565953,
    0.650970059,
    1.31679234,
    2.305363916,
    5.36679004,
    10.3433655,
]
cpu_7ndecide =
[
    1.3362E-05,
    0.002195104,
    0.003187973,
    0.0040663,
    0.005614731,
    0.008266143,
    0.012104929,
    0.014702145,
    0.018612573,
    0.030095512,
    0.04126148,
    0.049021429,
    0.076560898,
    0.100674108
]

#Begin Plotting

fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(7*cpu_7ntime, cpu_7nvd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(7*gpu_7ntime,gpu_7nvd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["CPU", "GPU"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, GPU vs CPU")

ax2.plot(7*cpu_time_7nvr, cpu_7nvr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(7*gpu_7ntime,gpu_7nvr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, GPU vs CPU")

ax3.plot(7*cpu_7ntime, cpu_7ndecide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean runtime (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(7*gpu_7ntime,gpu_7ndecide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, GPU vs CPU")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')

# %%
gpu_n2time = 
[
    100,
    125,
    150,
    200,
    250,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750
]
cpu_n2time = 
[
    25,
    50,
    75,
    100,
    125,
    150,
    175
]
cpu_time_n2vr = 
[
    25,
    50,
    75,
    100,
    125
]
gpu_n2vd = 
[
    0.0048269,
    0.0060002,
    0.007170599,
    0.0093563,
    0.0117676,
    0.014054299,
    0.01640905,
    0.019088199,
    0.023234099,
    0.022988699,
    0.02863265,
    0.02893155,
    0.0311247,
    0.033381101,
    0.03514595
]
gpu_n2vr =
[
    0.021742605,
    0.03420152,
    0.04678444,
    0.16335137,
    0.31863086,
    0.62664573,
    1.21444019,
    1.96703706,
    2.954906045,
    4.42985646,
    6.857692565,
    9.17047126,
    10.65110112,
    17.1531411,
    22.27869476
]
gpu_n2decide = 
[
    1.74E-05,
    2.06E-05,
    2.30E-05,
    0.00149893,
    0.003058925,
    0.00465002,
    0.0092637,
    0.01234142,
    0.018653475,
    0.02483498,
    0.03282266,
    0.0432739,
    0.05611574,
    0.07028079,
    0.0843548
]

cpu_n2vd = 
[
    0.00363628,
    0.02782463,
    0.095944835,
    0.256983915,
    0.475815795,
    0.80007531,
    1.48149357

]
cpu_n2vr =
[
    0.055270205,
    0.81490575,
    4.26258664,
    13.87689287,
    31.64415038
]
cpu_n2decide =
[
    0.00261786,
    0.020875015,
    0.07304889,
    0.16992249,
    0.334118665,
    0.58950077,
    0.88454872

]

#Begin Plotting

fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(cpu_n2time.^2, cpu_n2vd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(gpu_n2time.^2,gpu_n2vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["CPU", "GPU"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, GPU vs CPU")

ax2.plot(cpu_time_n2vr.^2, cpu_n2vr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(gpu_n2time.^2,gpu_n2vr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, GPU vs CPU")

ax3.plot(cpu_n2time.^2, cpu_n2decide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean runtime (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(gpu_n2time.^2,gpu_n2decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, GPU vs CPU")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')

# %%
# Out:
# 3-element Array{Int64,1}:
#  1
#  4
#  9
