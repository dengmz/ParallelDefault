# %%
using PyPlot; const plt = PyPlot;

# %%
Vd = [230.4,240.3,268,608,761]
Vr = [243.899, 258.399, 767.4, 1120.55, 1674.3]
Decide = [105.1, 213.301, 392.4, 964, 1352.9]
Vd_cpu = [530.5,1186.1,2119,3105,4964.9]
Vr_cpu = [196.4,716,1157000,3483000,7677000]
Decide_cpu = [277.9,798,1773,3476,6793]
time_cpu = [2500, 5625, 8000, 14400, 22500]
time = [2500, 8000, 30000, 90000, 250000]
time_stdpar = [2500,10000,22500,40000,90000,250000]
Vd_stdpar = [18.56, 95.75, 202.3, 347.4, 757, 2149]
Vr_stdpar = [77.8, 677, 1847, 6062, 31630, 257598]
Decide_stdpar = [15.39, 189.5, 317, 741, 2537, 12499]
Vd_old = [103.5, 253, 296, 330.3, 407, 378, 437]
Vr_old = []
Decide_old = [153.9, 298.9, 273, 401.1, 1080.7, 2359, 5370]
# Out:
# 7-element Array{Float64,1}:
#   153.9
#   298.9
#   273.0
#   401.1
#  1080.7
#  2359.0
#  5370.0

# %%
data = hcat(Vd,Vr,Decide)
data2 = hcat(Vd_cpu,Vr_cpu,time_cpu)
# Out:
# 5×3 Array{Float64,2}:
#   530.5  196.4       2500.0
#  1186.1  716.0       5625.0
#  2119.0    1.157e6   8000.0
#  3105.0    3.483e6  14400.0
#  4964.9    7.677e6  22500.0

# %%
fig,ax1 = plt.subplots(1)
ax1.plot(time, data, lw=2, marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("median (μs)") 
ax1.set_xlabel("Grid Size")
fig.legend(["Value of Default", "Value of Repayment", "Decision"])
fig.set_figheight(10)
fig.set_figwidth(14)
ax1.set_title("Benchmark of Three Components of Default Model by GPU")
# Out:
# Figure(PyObject <Figure size 1400x1000 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'Benchmark of Three Components of Default Model by GPU')

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(time_cpu, Vd_cpu, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("median (μs)") 
ax1.set_xlabel("Grid Size")
ax1.plot(time,Vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["CPU", "GPU"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, GPU vs CPU")

ax2.plot(time_cpu, Vr_cpu/1e6, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("median (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(time,Vr/1e6,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, GPU vs CPU")

ax3.plot(time_cpu, Decide_cpu, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("median (μs)") 
ax3.set_xlabel("Grid Size")
ax3.plot(time,Decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, GPU vs CPU")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')

# %%
Vd = [0.010330811,0.0149092,0.01554226,0.01898595,0.0234679,0.030124853,0.040909186,0.048484828]
Vr = [0.005730623,
0.0059065,
0.006105922,
0.00594906,
0.007445408,
0.013202525,
0.013224421,
0.013089871,
]
Decide = [0.0043382,
0.00530124,
0.008271306,
0.0210895,
0.07477759,
0.5596058,
1.28783554,
2.624506536
]
Update = [1.13E-02,
0.01810651,
0.0281298,
0.0818959,
0.30024561,
0.701087495,
1.32371813,
2.6971
]
Vd_cpu = [0.000276619,
0.002301644,
0.004512041,
0.009492124,
0.011564764,
0.017247236,
0.038075186,
0.06215833
]
Vr_cpu = [0.006913205,
0.102565745,
0.247352114,
0.522458908,
0.96900715,
1.6096785,
3.930659524,
8.422215724,
]
Decide_cpu = [0.000234728,
0.002040204,
0.003953054,
0.006879864,
0.011089838,
0.016148504,
0.032105191,
0.056447519
]
Update_cpu=[
    4.54E-05,
0.001044217,
0.000600985,
0.000674387,
0.001196874,
0.00118166,
0.001770133,
0.00347071
]
time_cpu = [2500, 10000, 125^2, 150^2, 175^2, 200^2, 250^2, 300^2]
time = [50^2, 100^2,150^2,200^2,300^2,400^2,500^2,600^2]
#time_stdpar = [2500,10000,22500,40000,90000,250000]
#Vd_stdpar = [18.56, 95.75, 202.3, 347.4, 757, 2149]
#Vr_stdpar = [77.8, 677, 1847, 6062, 31630, 257598]
#Decide_stdpar = [15.39, 189.5, 317, 741, 2537, 12499]
#Vd_old = [103.5, 253, 296, 330.3, 407, 378, 437]
#Vr_old = []
#Decide_old = [153.9, 298.9, 273, 401.1, 1080.7, 2359, 5370]
# Out:
# 8-element Array{Int64,1}:
#    2500
#   10000
#   22500
#   40000
#   90000
#  160000
#  250000
#  360000

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(time_cpu, Vd_cpu, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(time,Vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["CPU", "GPU"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, GPU vs CPU")

ax2.plot(time_cpu, Vr_cpu/1e6, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(time,Vr/1e6,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, GPU vs CPU")

ax3.plot(time_cpu, Decide_cpu, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(time,Decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, GPU vs CPU")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(time_stdpar, Vd_stdpar, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("median (μs)") 
ax1.set_xlabel("Grid Size")
ax1.plot(time,Vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["C++ stdpar CUDA", "Julia CUDA"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, C++ stdpar CUDA vs Julia CUDA")

ax2.plot(time_stdpar, Vr_stdpar, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("median (μs)") 
ax2.set_xlabel("Grid Size")
ax2.plot(time,Vr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment,  C++ stdpar CUDA vs Julia CUDA")

ax3.plot(time_stdpar, Decide_stdpar, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("median (μs)") 
ax3.set_xlabel("Grid Size")
ax3.plot(time,Decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision,  C++ stdpar CUDA vs Julia CUDA")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision,  C++ stdpar CUDA vs Julia CUDA')

# %%
gpu_time = 
[
    100,
    250,
    500,
    1000,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000,
    11250,
    12500,
    13750,
    15000,
    16250,
    17500,
    18750,
    20000
]
cpu_time = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000,
    1250,
    1500,
    2000,
    3000,
    4000,
    5000
]
gpu_vd = 
[
    0.0025648,
    0.002434,
    0.005,
    0.004699,
    0.004734,
    0.0057876,
    0.00557851,
    0.004258,
    0.00413129,
    0.007454,
    0.004341207,
    0.007769737,
    0.008501097,
    0.01456514,
    0.007473297,
    0.011747353,
    0.007448314,
    0.01198216
]
gpu_vr =
[
    0.000789731,
    0.000804,
    0.0021831,
    0.0019562,
    0.0021,
    0.0038018,
    0.003775141,
    0.0021725,
    0.002679047,
    0.00372097,
    0.00276107,
    0.005406123,
    0.005117402,
    0.006440763,
    0.005468006,
    0.008158667,
    0.005249583,
    0.0066596
]
gpu_decide = 
[
    0.000904302,
    0.0010326,
    0.00293,
    0.0027557,
    0.003025,
    0.01397209,
    0.01539667,
    0.0071063,
    0.059022251,
    0.042036328,
    0.125304887,
    0.248332983,
    0.377822631,
    0.14858899,
    0.502899269,
    0.204835643,
    0.695879143,
    0.25903506
]
cpu_time_vr = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000 
]
cpu_time = 
[
    100,
    175,
    250,
    375,
    500,
    750,
    1000,
    1250,
    1500,
    2500,
    3750,
    5000,
    7500,
    10000
]
cpu_vd = 
[
    0.000029513,
    0.002595088,
    0.003920655,
    0.005585921,
    0.007276034,
    0.0098881,
    0.014520751,
    0.017932855,
    0.021650492,
    0.03506699,
    0.046521847,
    0.057261686,
    0.085886324,
    0.116654339
]
cpu_vr =
[
    0.001082981,
    0.321565953,
    0.650970059,
    1.31679234,
    2.305363916,
    5.36679004,
    10.3433655,
]
cpu_decide =
[
    1.3362E-05,
    0.002195104,
    0.003187973,
    0.0040663,
    0.005614731,
    0.008266143,
    0.012104929,
    0.000198855,
    0.000309957,
    0.000857451,
    0.000794312,
    0.000966725,
    0.001565692,
    0.002165904
]
# Out:
# 14-element Array{Float64,1}:
#  1.3362e-5
#  0.002195104
#  0.003187973
#  0.0040663
#  0.005614731
#  0.008266143
#  0.012104929
#  0.000198855
#  0.000309957
#  0.000857451
#  0.000794312
#  0.000966725
#  0.001565692
#  0.002165904

# %%
fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(7*cpu_time, cpu_vd, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax1.set_ylabel("mean runtime (second)") 
ax1.set_xlabel("Grid Size")
ax1.plot(7*gpu_time,gpu_vd,lw=2, marker ="o",markersize=5, linestyle="--")
fig.legend(["CPU", "GPU"],loc="right")
fig.set_figheight(15)
fig.set_figwidth(14)
ax1.set_title("Comparison: Value of Default, GPU vs CPU")

ax2.plot(7*cpu_time_vr, cpu_vr, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax2.set_ylabel("mean runtime (second)") 
ax2.set_xlabel("Grid Size")
ax2.plot(7*gpu_time,gpu_vr,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Value of Repayment_CPU", "Value of Repayment_GPU"])
ax2.set_title("Comparison: Value of Repayment, GPU vs CPU")

ax3.plot(7*cpu_time, cpu_decide, lw=2, color = "gray", marker ="o",markersize=5, linestyle="--")
ax3.set_ylabel("mean runtime (second)") 
ax3.set_xlabel("Grid Size")
ax3.plot(7*gpu_time,gpu_decide,lw=2, marker ="o",markersize=5, linestyle="--")
#fig.legend(["Decision_CPU", "Decision_GPU"])
ax3.set_title("Comparison: Decision, GPU vs CPU")
# Out:
# Figure(PyObject <Figure size 1400x1500 with 3 Axes>)
# PyObject Text(0.5, 1.0, 'Comparison: Decision, GPU vs CPU')
